# %% [markdown]
# # shrek_units
# How many shreks tall is the Mount Everest? Now you can calculate that 😎
#
# ![](shrek1.png)

# %%
# !pip install shrek_units --index-url https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple/ --quiet
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Okay, it's time to answer the question!
#
# **How many shreks tall is Mount Verest?**

# %%
from shrek_units import to_shreks, ureg
print(to_shreks(8848.86 * ureg.meter))
# Out:
# 3641.5061728395062 shrek

# %% [markdown]
# Example of wrong-dimension usage:

# %%
try:
    to_shreks(5 * ureg.kilogram)
except Exception as e:
    print(f"Refused, as expected: {type(e).__name__}: {e}")
# Out:
# Refused, as expected: DimensionalityError: Cannot convert from 'kilogram' ([mass]) to 'shrek' ([length])

# %% [markdown]
# ### notes
# One _shrek_ stands at 2.43 m (8 ft) - based on the information gathered from Shrek's character bio in the _Shrek 2_ videogame. There are several sources defining Shrek's height anywhere between 7 and 8 feet. For example, there's a size chart posted somewhere on X in 2022, stating that he is actually 7 ft tall. However, I've decided to go with the information from this 2004 bio. (it's an honour to have been born in the same year as this masterpiece)
